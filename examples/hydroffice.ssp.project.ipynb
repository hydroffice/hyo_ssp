# %% [markdown]
# # hydroffice.ssp.project

# %%
from hydroffice.ssp import project

# %% [markdown]
# ## Set the logging

# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.NOTSET)
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)  # change to WARNING to reduce verbosity, DEBUG for high verbosity
ch_formatter = logging.Formatter('%(levelname)-9s %(name)s.%(funcName)s:%(lineno)d > %(message)s')
ch.setFormatter(ch_formatter)
logger.addHandler(ch)

# %% [markdown]
# ## Run the project
#
# Create a project without listeners and atlases:

# %%
prj = project.Project(with_listeners=False, with_woa09=False, with_rtofs=False)
prj.release()
# Out:
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ##############################################################
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ##############################################################
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###          Configuration file for SSP library             ##
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###          Configuration file for SSP library             ##
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                                                         ##
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                                                         ##
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ### This file is loaded by project.py                       ##
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ### This file is loaded by project.py                       ##
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ### Lines starting with '#' or a white-space are ignored    ##
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ### Lines starting with '#' or a white-space are ignored    ##
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ##############################################################
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ##############################################################
# DEBUG:hydroffice.ssp.settings:config.ini: skipping zero length line
# DEBUG     hydroffice.ssp.settings.load_config:125 > config.ini: skipping zero length line
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                    General settings                    ###
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                    General settings                    ###
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # oceanographic data sources: RTOFS, WOA09, WOA13 [default value if empty: WOA09]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # oceanographic data sources: RTOFS, WOA09, WOA13 [default value if empty: WOA09]
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> RTOFS: a real-time model (requires internet connectivity).
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> RTOFS: a real-time model (requires internet connectivity).
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> WOA09: oceanographic atlas (usually installed together with the SSP library).
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> WOA09: oceanographic atlas (usually installed together with the SSP library).
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> WOA13: oceanographic atlas (future development)
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> WOA13: oceanographic atlas (future development)
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> ssp_extension_source +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> ssp_extension_source +
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> ssp_salinity_source +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> ssp_salinity_source +
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> ssp_temp_sal_source +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> ssp_temp_sal_source +
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> sis_server_source +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> sis_server_source +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Path to WOA09 grid files [empty: default path]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Path to WOA09 grid files [empty: default path]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> woa_path +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> woa_path +
# INFO:hydroffice.ssp.settings:default woa path: C:\Users\gmas\Documents\HydrOffice 0.2.0\SSP 0.2.0\Atlases\woa09
# INFO      hydroffice.ssp.settings.load_config:182 > default woa path: C:\Users\gmas\Documents\HydrOffice 0.2.0\SSP 0.2.0\Atlases\woa09
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Profile creation: Portion of the sensor cast to use:
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Profile creation: Portion of the sensor cast to use:
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> down: downcast [default if empty]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> down: downcast [default if empty]
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> up:   upcast
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> up:   upcast
# DEBUG:hydroffice.ssp.settings:config.ini: skipping zero length line
# DEBUG     hydroffice.ssp.settings.load_config:125 > config.ini: skipping zero length line
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                  Processing settings                   ###
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                  Processing settings                   ###
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> ssp_up_or_down +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> ssp_up_or_down +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Profile export: True -> automatically export certain file formats
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Profile export: True -> automatically export certain file formats
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #                         after network transmission.
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #                         after network transmission.
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #                 False [default]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #                 False [default]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> auto_export_on_send +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> auto_export_on_send +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Profile export: True -> automatically export certain file formats
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Profile export: True -> automatically export certain file formats
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #                         when the SIS server sends a cast. [Default]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #                         when the SIS server sends a cast. [Default]
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #                 False
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #                 False
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> auto_export_on_server_send +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> auto_export_on_server_send +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Profile export: True -> user specifies the file on export
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Profile export: True -> user specifies the file on export
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #                 False -> system creates file based on input name [default]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #                 False -> system creates file based on input name [default]
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # WARNING: does not apply to "auto_export_on_server_send".
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # WARNING: does not apply to "auto_export_on_server_send".
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> user_export_prompt_filename +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> user_export_prompt_filename +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping zero length line
# DEBUG     hydroffice.ssp.settings.load_config:125 > config.ini: skipping zero length line
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                  Caris File settings                   ###
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                  Caris File settings                   ###
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # If true, update the caris file in output
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # If true, update the caris file in output
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # if false, overwrite such a file [default]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # if false, overwrite such a file [default]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> user_append_caris_file +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> user_append_caris_file +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # If true, update the caris file in output
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # If true, update the caris file in output
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # if false, overwrite such a file [default]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # if false, overwrite such a file [default]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> server_append_caris_file +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> server_append_caris_file +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping zero length line
# DEBUG     hydroffice.ssp.settings.load_config:125 > config.ini: skipping zero length line
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                  Recipients settings                   ###
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                  Recipients settings                   ###
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Client list: each row is a SSP recipient with variable protocols.
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Client list: each row is a SSP recipient with variable protocols.
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> client_list + "Local test":127.0.0.1:4001:SIS
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> client_list + "Local test":127.0.0.1:4001:SIS
# INFO:hydroffice.ssp.pkg_clients:new client: "Local test"(127.0.0.1:4001) SIS
# INFO      hydroffice.ssp.pkg_clients.__init__:18 > new client: "Local test"(127.0.0.1:4001) SIS
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="Langseth SIS":192.168.3.101:4001:SIS
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="Langseth SIS":192.168.3.101:4001:SIS
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="R/V Falkor EM302":10.23.10.50:4001:SIS
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="R/V Falkor EM302":10.23.10.50:4001:SIS
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="R/V Falkor EM710":10.23.10.51:4001:SIS
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="R/V Falkor EM710":10.23.10.51:4001:SIS
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="R/V Revelle EM122":10.110.149.50:4001:SIS
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="R/V Revelle EM122":10.110.149.50:4001:SIS
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="Ophelia SIS":192.168.8.213:4001:SIS
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="Ophelia SIS":192.168.8.213:4001:SIS
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="Ophelia HYPACK":192.168.8.213:2006:HYPACK
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="Ophelia HYPACK":192.168.8.213:2006:HYPACK
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="Ophelia PDS2000":192.168.8.213:2002:PDS2000
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="Ophelia PDS2000":192.168.8.213:2002:PDS2000
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #client_list="Ophelia QINSY":192.168.8.213:14001:QINSY
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #client_list="Ophelia QINSY":192.168.8.213:14001:QINSY
# DEBUG:hydroffice.ssp.settings:config.ini: skipping zero length line
# DEBUG     hydroffice.ssp.settings.load_config:125 > config.ini: skipping zero length line
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                     SIS settings                      ###
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                     SIS settings                      ###
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # SIS: port to listen to for broadcasts [default: 16103]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # SIS: port to listen to for broadcasts [default: 16103]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> km_listen_port +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> km_listen_port +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # SIS: listen interval for broadcasts [default: 1]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # SIS: listen interval for broadcasts [default: 1]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> km_listen_timeout +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> km_listen_timeout +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Immediate SSP application for SIS.
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Immediate SSP application for SIS.
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> True:  casts formatted for immediate application (not user confirmation). [default]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> True:  casts formatted for immediate application (not user confirmation). [default]
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> False: SIS requests user confirmation prior to application.
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> False: SIS requests user confirmation prior to application.
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # WARNING: in Server Mode, casts always formatted for immediate SIS application.
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # WARNING: in Server Mode, casts always formatted for immediate SIS application.
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> sis_auto_apply_manual_casts +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> sis_auto_apply_manual_casts +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # SIS server: augment SSP with surface sound speed measurements from depth datagram [true]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # SIS server: augment SSP with surface sound speed measurements from depth datagram [true]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> server_apply_surface_sound_speed +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> server_apply_surface_sound_speed +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping zero length line
# DEBUG     hydroffice.ssp.settings.load_config:125 > config.ini: skipping zero length line
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                   Sippican settings                   ###
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                   Sippican settings                   ###
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   #
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   #
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Sippican: port to listen to for input [default: 2002]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Sippican: port to listen to for input [default: 2002]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> sippican_listen_port +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> sippican_listen_port +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # Sippican: listen interval for input [default: 1]
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # Sippican: listen interval for input [default: 1]
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> sippican_listen_timeout +
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> sippican_listen_timeout +
# DEBUG:hydroffice.ssp.settings:config.ini: skipping zero length line
# DEBUG     hydroffice.ssp.settings.load_config:125 > config.ini: skipping zero length line
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   ###                     MVP settings                      ###
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   ###                     MVP settings                      ###
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # MVP: port and ip to listen to for input
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # MVP: port and ip to listen to for input
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_ip_address + 127.0.0.1
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_ip_address + 127.0.0.1
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_listen_port + 2006
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_listen_port + 2006
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # MVP: listen interval for input
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # MVP: listen interval for input
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_listen_timeout + 1
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_listen_timeout + 1
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # MVP: transmission protocol, currently supported:
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # MVP: transmission protocol, currently supported:
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> NAVO_ISS60 (transmits data in chunks to avoid overflow of UDP packet max size, necessary for deep ocean)
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> NAVO_ISS60 (transmits data in chunks to avoid overflow of UDP packet max size, necessary for deep ocean)
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> UNDEFINED (transmits entire datagram at once, okay for short casts)
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> UNDEFINED (transmits entire datagram at once, okay for short casts)
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_transmission_protocol + NAVO_ISS60
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_transmission_protocol + NAVO_ISS60
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # MVP: data format, currently supported:
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # MVP: data format, currently supported:
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> CALC
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> CALC
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> ASVP
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> ASVP
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> S12
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> S12
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_format + S12
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_format + S12
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # MVP: raw sensor data (not currently used):
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # MVP: raw sensor data (not currently used):
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_winch_port + 3601
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_winch_port + 3601
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_fish_port + 3602
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_fish_port + 3602
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_nav_port + 3603
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_nav_port + 3603
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_system_port + 3604
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_system_port + 3604
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_sw_version + 2.47
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_sw_version + 2.47
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_instrument_id + M
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_instrument_id + M
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # MVP: sensor type, the following are supported
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # MVP: sensor type, the following are supported
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> AML_uSVP
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> AML_uSVP
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> AML_uSVPT
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> AML_uSVPT
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> AML_Smart_SVP
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> AML_Smart_SVP
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> AML_uCTD
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> AML_uCTD
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> AML_uCTD+
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> AML_uCTD+
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> Valeport_SVPT
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> Valeport_SVPT
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> SBE_911+
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> SBE_911+
# DEBUG:hydroffice.ssp.settings:config.ini: skipping comment line:
#   # -> SBE_49
# DEBUG     hydroffice.ssp.settings.load_config:128 > config.ini: skipping comment line:
#   # -> SBE_49
# DEBUG:hydroffice.ssp.settings:config.ini: valid pair: -> mvp_instrument + AML_uSVPT
# DEBUG     hydroffice.ssp.settings.load_config:139 > config.ini: valid pair: -> mvp_instrument + AML_uSVPT
